# %% [markdown]
# # Linly-Dubbing Kaggle WebUI (v4.1 - Technical Fixes Applied)
#
# This notebook is optimized for running **Linly-Dubbing** on Kaggle with **Dual T4 GPUs**. Recent updates include fixes for submodule path conflicts and more robust dependency installation.
#
# ### 🚀 Key Improvements in v4.1
# - **Submodule Isolation**: Fixed `sys.path` order to prevent submodules (like demucs) from shadowing main project files.
# - **Robust Dependencies**: Improved bash syntax and error handling in dependency installation.
# - **Resilient AI Model Downloads**: Added retry capability for Hugging Face snapshot downloads to handle server timeouts.
# - **Python 3.12 Compatibility**: Enhanced system library installation for building audio tools from source.
#
# ### 📋 Execution Guide
# 1. **Step 1**: Clone repository and check GPU availability
# 2. **Step 2**: Install all dependencies (Uses robust multi-stage install)
# 3. **Step 3**: Download required AI models
# 4. **Step 4**: Launch the WebUI
#
# ### ⚙️ Kaggle Setup Requirements
# - Enable **GPU T4 x2** in Settings → Accelerator
# - Enable **Internet** in Settings → Internet
#
# ---

# %%
# ============================================================================
# Step 0: 环境检测 (Environment Detection)
# ============================================================================

import os
import sys
import platform
import subprocess
import shutil

print("=" * 60)
print("🔍 Kaggle 运行环境检测")
print("=" * 60)

# Python 信息
print("\n📊 Python 环境:")
print(f"   Python 版本: {sys.version.split()[0]}")
print(f"   Python 路径: {sys.executable}")

# CUDA 信息
print("\n🎮 CUDA 环境:")
try:
    import torch
    print(f"   PyTorch 版本: {torch.__version__}")
    print(f"   CUDA 可用: {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"   CUDA 版本: {torch.version.cuda}")
        try:
            print(f"   cuDNN 版本: {torch.backends.cudnn.version()}")
        except: print("   cuDNN 版本: 获取失败")
except ImportError:
    print("   ⚠️ PyTorch 未安装")

# 磁盘空间
stat = shutil.disk_usage('/kaggle/working')
print(f"\n💾 磁盘可用空间: {stat.free / (1024**3):.1f} GB")

# 预装 Python 包 (Handle torchvision error gracefully)
print("\n📦 预装 Python 包 (关键):")
for pkg in ['torch', 'torchvision', 'numpy', 'pip']:
    try: 
        m = __import__(pkg)
        print(f"   ✅ {pkg}: {getattr(m, '__version__', 'OK')}")
    except Exception as e:
        print(f"   ⚠️ {pkg}: 导入失败 ({type(e).__name__})")

print("\n" + "=" * 60)
print("✅ 环境检测完成!")
print("=" * 60)
# Out:
# ============================================================
# 🔍 Kaggle 运行环境检测
# ============================================================
#
# 📊 Python 环境:
#    Python 版本: 3.12.12
#    Python 路径: /usr/bin/python3
#
# 🎮 CUDA 环境:
#    PyTorch 版本: 2.8.0+cu126
#    CUDA 可用: True
#    CUDA 版本: 12.6
#    cuDNN 版本: 91002
#
# 💾 磁盘可用空间: 3.4 GB
#
# 📦 预装 Python 包 (关键):
#    ✅ torch: 2.8.0+cu126
#    ✅ torchvision: 0.23.0+cu126
#    ✅ numpy: 2.0.2
#    ✅ pip: 24.1.2
#
# ============================================================
# ✅ 环境检测完成!
# ============================================================

# %%
# ============================================================================
# Step 1: Clone Repository and Check GPU
# ============================================================================

import os
import torch
import shutil

print("=" * 60)
print("🔍 GPU Detection")
print("=" * 60)
if torch.cuda.is_available():
    gpu_count = torch.cuda.device_count()
    print(f"✅ Found {gpu_count} GPU(s):")
    for i in range(gpu_count):
        print(f"   - GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("❌ No GPU detected! Please enable GPU T4 x2 in settings.")

print("\n" + "=" * 60)
print("📦 Cloning Repository")
print("=" * 60)

# Always remove old directory and clone fresh to ensure latest changes
project_path = '/kaggle/working/Linly-Dubbing'
if os.path.exists(project_path):
    print(f"Removing existing directory: {project_path}")
    shutil.rmtree(project_path)

# !cd /kaggle/working && git clone https://github.com/infinite-gaming-studio/Linly-Dubbing.git --depth 1

# %cd /kaggle/working/Linly-Dubbing

print("\nInitializing submodules...")
# !git submodule update --init --recursive

print("\n✅ Step 1 Complete!")
# Out:
# ============================================================
# 🔍 GPU Detection
# ============================================================
# ✅ Found 2 GPU(s):
#    - GPU 0: Tesla T4
#    - GPU 1: Tesla T4
#
# ============================================================
# 📦 Cloning Repository
# ============================================================
# Removing existing directory: /kaggle/working/Linly-Dubbing
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# chdir: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Cloning into 'Linly-Dubbing'...
# remote: Enumerating objects: 1043, done.
# remote: Counting objects: 100% (1043/1043), done.
# remote: Compressing objects: 100% (863/863), done.
# remote: Total 1043 (delta 125), reused 991 (delta 120), pack-reused 0 (from 0)
# Receiving objects: 100% (1043/1043), 39.79 MiB | 36.02 MiB/s, done.
# Resolving deltas: 100% (125/125), done.
# /kaggle/working/Linly-Dubbing
#
# Initializing submodules...
# Submodule 'CosyVoice' (https://github.com/FunAudioLLM/CosyVoice.git) registered for path 'CosyVoice'
# Cloning into '/kaggle/working/Linly-Dubbing/CosyVoice'...
# Submodule path 'CosyVoice': checked out '6be8d0fc367f48c46a671edc16a99b9728038cb7'
# Submodule 'third_party/Matcha-TTS' (https://github.com/shivammehta25/Matcha-TTS.git) registered for path 'CosyVoice/third_party/Matcha-TTS'
# Cloning into '/kaggle/working/Linly-Dubbing/CosyVoice/third_party/Matcha-TTS'...
# Submodule path 'CosyVoice/third_party/Matcha-TTS': checked out 'dd9105b34bf2be2230f4aa1e4769fb586a3c824e'
#
# ✅ Step 1 Complete!

# %%
# ============================================================================
# Step 2: Install Dependencies (Final Version - Numpy Compatibility Fix)
# ============================================================================

print("=" * 60)
print("📦 Installing System Dependencies")
print("=" * 60)

# 1. Install system tools required for build
# !apt-get update -qq
# !apt-get install -y -qq build-essential libfst-dev libfst-tools python3-dev ffmpeg \
    libavdevice-dev libavfilter-dev libavformat-dev libavcodec-dev \
    libswresample-dev libswscale-dev libavutil-dev

print("\n🐍 Installing Python Dependencies with Strict Version Control")
print("=" * 60)

# 2. CRITICAL: Install numpy and scipy FIRST with strict versions to prevent upgrades
print("Step 1/10: Installing numpy and scipy with strict versions...")
# !pip install -q "numpy>=1.24.0,<2.0" "scipy>=1.10.0,<1.12.0"

# 3. Install other core scientific packages with compatible versions
print("Step 2/10: Installing core scientific packages...")
# !pip install -q "pandas>=2.0,<2.3" "scikit-learn>=1.3.0"

# 4. Update pip tools
print("Step 3/10: Updating pip tools...")
# !pip install --upgrade -q pip setuptools wheel

# 5. Install submodule base dependencies
print("Step 4/10: Installing submodule base dependencies...")
# !pip install -q dora-search diffq einops julius lameenc tqdm treetable hydra-core hydra-colorlog pyyaml

# 6. Install TTS/audio dependencies with compatible versions
print("Step 5/10: Installing audio and ML dependencies...")
# !pip install -q cython soundfile librosa inflect fsspec aiohttp packaging
# !pip install -q "transformers>=4.39.0,<4.40.0" encodec unidecode num2words

# 7. Patch requirements.txt to avoid conflicts
print("Step 6/10: Patching requirements.txt...")
# !sed -i 's/numpy<2.0.0/# numpy<2.0.0 # Already installed/g' requirements.txt
# !sed -i 's/^scipy/# scipy # Already installed/g' requirements.txt
# !sed -i 's/transformers==4.39.3/# transformers==4.39.3 # Already installed/g' requirements.txt

# 8. Patch TTS for Python 3.12 compatibility
if os.path.exists('submodules/TTS/setup.py'):
    # !sed -i 's/Version(python_version) >= Version(\"3.12\"): /Version(python_version) >= Version(\"3.13\"): /g' submodules/TTS/setup.py
    # !sed -i 's/python_requires=\">=3.9.0, <3.12\",/python_requires=\">=3.9.0, <3.13\",/g' submodules/TTS/setup.py

# 9. Optional: Try pynini (allow failure - it's not critical)
print("Step 7/10: Attempting pynini installation (optional)...")
# !pip install -q pynini==2.1.5 --no-cache-dir 2>/dev/null || echo "⚠️  pynini installation skipped (non-critical)"

# 10. Install core requirements (numpy/scipy already installed)
print("Step 8/10: Installing core requirements...")
# !pip install -q -r requirements.txt

# 11. Install whisperX dependencies
print("Step 9/10: Installing whisperX dependencies...")
# !pip install -q pyannote.audio==3.1.1 faster-whisper==1.0.0

# 12. Install submodules with improved handling
print("Step 10/10: Installing submodules...")
submodules_info = [
    ('submodules/demucs', 'demucs'),
    ('submodules/whisper', 'openai-whisper'),
    ('submodules/whisperX', 'whisperX'),
    ('submodules/TTS', 'TTS')
]

for sm_path, sm_name in submodules_info:
    if os.path.exists(sm_path):
        print(f"   - Installing {sm_name}...")
        result = !pip install -q -e "{sm_path}" 2>&1
        if result and 'error' in str(result).lower():
            print(f"     Retrying {sm_name} without dependencies...")
            # !pip install -q -e "{sm_path}" --no-deps || echo f"   ⚠️  {sm_name} install failed (will use sys.path fallback)"
        else:
            print(f"     ✓ {sm_name} installed successfully")

# 13. Final tools
print("\nInstalling final tools...")
# !pip install -q loguru yt-dlp "gradio>=4.44,<5.0"

# 14. Verify critical package versions
print("\n" + "=" * 60)
print("🔍 Verifying Critical Package Versions")
print("=" * 60)
import sys
for pkg in ['numpy', 'scipy', 'transformers', 'pandas']:
    try:
        mod = __import__(pkg)
        ver = getattr(mod, '__version__', 'unknown')
        print(f"   ✓ {pkg}: {ver}")
    except ImportError:
        print(f"   ✗ {pkg}: NOT INSTALLED")

print("\n" + "=" * 60)
print("✅ Step 2 Complete!")
print("=" * 60)
# Out:
# ============================================================
# 📦 Installing System Dependencies
# ============================================================
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# 🐍 Installing Python Dependencies with Strict Version Control
# ============================================================
# Step 1/10: Installing numpy and scipy with strict versions...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pyannote-metrics 4.0.0 requires numpy>=2.2.2, but you have numpy 1.26.4 which is incompatible.
# pyannote-metrics 4.0.0 requires scipy>=1.15.1, but you have scipy 1.11.4 which is incompatible.
# openai-whisper 20231117 requires triton<3,>=2.0.0; platform_machine == "x86_64" and sys_platform == "linux" or sys_platform == "linux2", but you have triton 3.4.0 which is incompatible.
# pyannote-core 6.0.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.47.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# sentence-transformers 5.1.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.3 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 12.0 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# Step 2/10: Installing core scientific packages...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pyannote-metrics 4.0.0 requires numpy>=2.2.2, but you have numpy 1.26.4 which is incompatible.
# pyannote-metrics 4.0.0 requires scipy>=1.15.1, but you have scipy 1.11.4 which is incompatible.
# pyannote-core 6.0.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.47.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.4 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 12.0 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
# Step 3/10: Updating pip tools...
# Step 4/10: Installing submodule base dependencies...
# Step 5/10: Installing audio and ML dependencies...
# Step 6/10: Patching requirements.txt...
# Step 7/10: Attempting pynini installation (optional)...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# ⚠️  pynini installation skipped (non-critical)
# Step 8/10: Installing core requirements...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# ERROR: Failed to build 'pynini' when getting requirements to build wheel
# Step 9/10: Installing whisperX dependencies...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# openai-whisper 20231117 requires triton<3,>=2.0.0; platform_machine == "x86_64" and sys_platform == "linux" or sys_platform == "linux2", but you have triton 3.4.0 which is incompatible.
# ydata-profiling 4.18.1 requires numpy<2.4,>=1.22, but you have numpy 2.4.1 which is incompatible.
# ydata-profiling 4.18.1 requires scipy<1.17,>=1.8, but you have scipy 1.17.0 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.47.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# sentence-transformers 5.1.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.1 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.4.1 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.4.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.1 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 12.0 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.1 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# Step 10/10: Installing submodules...
#    - Installing demucs...
#      ✓ demucs installed successfully
#    - Installing openai-whisper...
#      Retrying openai-whisper without dependencies...
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for openai-whisper (pyproject.toml) ... done
#    - Installing whisperX...
#      Retrying whisperX without dependencies...
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for whisperx (pyproject.toml) ... done
#    - Installing TTS...
#      Retrying TTS without dependencies...
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build editable did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build editable ... error
# ERROR: Failed to build 'file:///kaggle/working/Linly-Dubbing/submodules/TTS' when getting requirements to build editable
# f   ⚠️  TTS install failed (will use sys.path fallback)
#
# Installing final tools...
#
# ============================================================
# 🔍 Verifying Critical Package Versions
# ============================================================
#    ✓ numpy: 2.0.2
#    ✓ scipy: 1.15.3
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
#    ✓ transformers: 4.39.3
#    ✓ pandas: 2.2.3
#
# ============================================================
# ✅ Step 2 Complete!
# ============================================================

# %%
# ============================================================================
# Step 3: Download AI Models
# ============================================================================

print("=" * 60)
print("🤖 Downloading AI Models")
print("=" * 60)

# !mkdir -p models/ASR/whisper
wav2vec_path = 'models/ASR/whisper/wav2vec2_fairseq_base_ls960_asr_ls960.pth'
if not os.path.exists(wav2vec_path):
    # !wget -nc https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth -O {wav2vec_path}

# Use download script
# !python scripts/huggingface_download.py

print("\n✅ Step 3 Complete!")
# Out:
# ============================================================
# 🤖 Downloading AI Models
# ============================================================
# --2026-01-30 05:38:14--  https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# Resolving download.pytorch.org (download.pytorch.org)... 52.85.12.126, 52.85.12.3, 52.85.12.82, ...
# Connecting to download.pytorch.org (download.pytorch.org)|52.85.12.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 377664473 (360M) [application/x-www-form-urlencoded]
# Saving to: ‘models/ASR/whisper/wav2vec2_fairseq_base_ls960_asr_ls960.pth’
#
# models/ASR/whisper/ 100%[===================>] 360.17M   262MB/s    in 1.4s
#
# 2026-01-30 05:38:16 (262 MB/s) - ‘models/ASR/whisper/wav2vec2_fairseq_base_ls960_asr_ls960.pth’ saved [377664473/377664473]
#
# Downloading coqui/XTTS-v2 to models/TTS/XTTS-v2 (Attempt 1/5)...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 18 files:   0%|                                 | 0/18 [00:00<?, ?it/s]
# config.json: 4.37kB [00:00, 12.5MB/s]
#
# de_sample.wav:   0%|                                 | 0.00/299k [00:00<?, ?B/s]
#
# de_sample.wav: 100%|█████████████████████████| 299k/299k [00:00<00:00, 8.22MB/s]
#
# hash.md5: 100%|███████████████████████████████| 32.0/32.0 [00:00<00:00, 171kB/s]
#
# model.pth:   0%|                                    | 0.00/1.87G [00:00<?, ?B/s]
#
#
# en_sample.wav:   0%|                                 | 0.00/299k [00:00<?, ?B/s]
#
#
#
# en_sample.wav: 100%|█████████████████████████| 299k/299k [00:00<00:00, 37.9MB/s]
#
#
#
# mel_stats.pth:   0%|                                | 0.00/1.07k [00:00<?, ?B/s]
#
#
#
#
# .gitattributes: 1.52kB [00:00, 8.41MB/s]A
# Fetching 18 files:   6%|█▍                       | 1/18 [00:00<00:07,  2.23it/s]
#
#
#
#
# README.md: 4.26kB [00:00, 16.3MB/s]A
#
#
#
#
#
# es_sample.wav: 100%|█████████████████████████| 330k/330k [00:00<00:00, 8.67MB/s]
# LICENSE.txt: 4.01kB [00:00, 6.75MB/s]
#
#
#
#
# fr_sample.wav: 100%|█████████████████████████| 432k/432k [00:00<00:00, 40.8MB/s]
#
#
#
#
# tr_sample.wav: 100%|█████████████████████████| 299k/299k [00:00<00:00, 39.9MB/s]
#
#
#
#
# zh-cn-sample.wav:   0%|                              | 0.00/383k [00:00<?, ?B/s]
#
#
#
#
# ja-sample.wav:   0%|                                 | 0.00/285k [00:00<?, ?B/s]
#
#
#
#
#
# zh-cn-sample.wav: 100%|██████████████████████| 383k/383k [00:00<00:00, 9.24MB/s]
# pt_sample.wav: 100%|█████████████████████████| 445k/445k [00:00<00:00, 10.6MB/s]
#
#
#
#
# speakers_xtts.pth:   0%|                            | 0.00/7.75M [00:00<?, ?B/s]
#
#
#
#
#
# vocab.json: 361kB [00:00, 122MB/s]
#
#
#
#
#
# ja-sample.wav: 100%|█████████████████████████| 285k/285k [00:00<00:00, 2.78MB/s]
#
#
#
# mel_stats.pth: 100%|███████████████████████| 1.07k/1.07k [00:00<00:00, 4.27kB/s]
#
#
#
#
# speakers_xtts.pth: 100%|███████████████████| 7.75M/7.75M [00:00<00:00, 20.4MB/s]
#
#
# dvae.pth:   5%|█▎                           | 9.48M/211M [00:00<00:17, 11.4MB/s]
# model.pth:   0%|                           | 1.44M/1.87G [00:01<22:41, 1.37MB/s]
# model.pth:   0%|                           | 1.93M/1.87G [00:01<21:29, 1.45MB/s]
# model.pth:   0%|                           | 2.09M/1.87G [00:01<21:25, 1.45MB/s]
# model.pth:   0%|                           | 3.07M/1.87G [00:01<12:20, 2.52MB/s]
# model.pth:   0%|                           | 5.90M/1.87G [00:01<05:14, 5.92MB/s]
#
# dvae.pth:  36%|██████████▌                  | 76.5M/211M [00:01<00:03, 42.9MB/s]
# model.pth:   4%|█▏                          | 76.6M/1.87G [00:01<00:14, 122MB/s]
# model.pth:   8%|██▎                          | 151M/1.87G [00:02<00:07, 222MB/s]
# model.pth:  12%|███▍                         | 218M/1.87G [00:02<00:05, 307MB/s]
# model.pth:  15%|████▍                        | 288M/1.87G [00:02<00:04, 331MB/s]
# model.pth:  20%|█████▋                       | 365M/1.87G [00:02<00:07, 208MB/s]
# model.pth:  27%|███████▋                     | 499M/1.87G [00:03<00:04, 321MB/s]
# model.pth:  30%|████████▊                    | 566M/1.87G [00:03<00:04, 288MB/s]
#
# dvae.pth:  68%|████████████████████▍         | 143M/211M [00:03<00:01, 41.6MB/s]
# model.pth:  37%|██████████▊                  | 700M/1.87G [00:03<00:02, 394MB/s]
# model.pth:  41%|███████████▉                 | 767M/1.87G [00:03<00:02, 408MB/s]
# model.pth:  50%|██████████████▍              | 931M/1.87G [00:03<00:01, 603MB/s]
# model.pth:  57%|███████████████▉            | 1.07G/1.87G [00:04<00:01, 650MB/s]
#
# dvae.pth: 100%|██████████████████████████████| 211M/211M [00:04<00:00, 49.8MB/s]
# Fetching 18 files:  28%|██████▉                  | 5/18 [00:04<00:12,  1.07it/s]
# model.pth:  64%|█████████████████▉          | 1.20G/1.87G [00:04<00:00, 670MB/s]
# model.pth:  71%|███████████████████▉        | 1.33G/1.87G [00:04<00:00, 680MB/s]
# model.pth:  79%|█████████████████████▉      | 1.47G/1.87G [00:04<00:00, 777MB/s]
# model.pth:  86%|███████████████████████▉    | 1.60G/1.87G [00:04<00:00, 793MB/s]
# model.pth: 100%|████████████████████████████| 1.87G/1.87G [00:04<00:00, 385MB/s]
# Fetching 18 files: 100%|████████████████████████| 18/18 [00:05<00:00,  3.45it/s]
# Successfully downloaded coqui/XTTS-v2
# Downloading Qwen/Qwen1.5-4B-Chat to models/LLM/Qwen1.5-4B-Chat (Attempt 1/5)...
# Fetching 12 files:   0%|                                 | 0/12 [00:00<?, ?it/s]
# README.md: 4.27kB [00:00, 16.2MB/s]
#
# model-00002-of-00002.safetensors:   0%|             | 0.00/3.91G [00:00<?, ?B/s]
#
# config.json: 100%|█████████████████████████████| 662/662 [00:00<00:00, 6.25MB/s]
#
#
# model.safetensors.index.json: 39.6kB [00:00, 122MB/s][A
#
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
#
# .gitattributes: 1.52kB [00:00, 7.86MB/s]A
# Fetching 12 files:   8%|██                       | 1/12 [00:00<00:02,  4.68it/s]
#
#
# model-00001-of-00002.safetensors:   0%|             | 0.00/3.99G [00:00<?, ?B/s]
#
#
#
# generation_config.json: 100%|██████████████████| 206/206 [00:00<00:00, 1.95MB/s]
#
#
#
#
# LICENSE: 7.28kB [00:00, 32.9MB/s]A
#
#
#
#
# tokenizer.json: 7.03MB [00:00, 86.0MB/s]
# vocab.json: 2.78MB [00:00, 45.4MB/s]
#
#
# merges.txt: 1.67MB [00:00, 81.2MB/s]A
# Fetching 12 files:  50%|████████████▌            | 6/12 [00:00<00:00, 15.79it/s]
#
# tokenizer_config.json: 1.29kB [00:00, 5.87MB/s]A
#
# model-00002-of-00002.safetensors:   0%|    | 825k/3.91G [00:01<1:48:43, 599kB/s]
#
#
# model-00001-of-00002.safetensors:   0%|    | 700k/3.99G [00:01<2:02:49, 541kB/s]
# model-00002-of-00002.safetensors:   1%|    | 21.9M/3.91G [00:01<03:23, 19.2MB/s]
#
#
# model-00001-of-00002.safetensors:   0%|    | 13.0M/3.99G [00:01<05:36, 11.8MB/s]
# model-00002-of-00002.safetensors:   1%|    | 34.9M/3.91G [00:01<02:03, 31.5MB/s]
# model-00002-of-00002.safetensors:   1%|    | 47.9M/3.91G [00:01<01:52, 34.3MB/s]
# model-00002-of-00002.safetensors:   2%|    | 60.9M/3.91G [00:02<01:34, 40.8MB/s]
#
#
# model-00001-of-00002.safetensors:   0%|    | 19.0M/3.99G [00:02<06:06, 10.8MB/s]
# model-00002-of-00002.safetensors:   2%|    | 87.0M/3.91G [00:02<00:54, 70.7MB/s]
#
#
# model-00001-of-00002.safetensors:   1%|    | 42.7M/3.99G [00:02<02:13, 29.6MB/s]
# model-00002-of-00002.safetensors:   4%|▏    | 154M/3.91G [00:03<00:48, 78.1MB/s]
#
#
# model-00001-of-00002.safetensors:   2%|    | 84.1M/3.99G [00:03<01:40, 38.8MB/s]
# model-00002-of-00002.safetensors:   5%|▏    | 191M/3.91G [00:03<00:43, 86.2MB/s]
# model-00002-of-00002.safetensors:   7%|▍     | 257M/3.91G [00:03<00:27, 132MB/s]
#
#
# model-00001-of-00002.safetensors:   3%|▏    | 116M/3.99G [00:03<01:19, 49.0MB/s]
# model-00002-of-00002.safetensors:   9%|▌     | 336M/3.91G [00:04<00:24, 146MB/s]
# model-00002-of-00002.safetensors:  10%|▌     | 383M/3.91G [00:04<00:20, 173MB/s]
# model-00002-of-00002.safetensors:  11%|▋     | 412M/3.91G [00:04<00:24, 142MB/s]
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 144M/3.99G [00:04<01:36, 39.9MB/s]
# model-00002-of-00002.safetensors:  11%|▋     | 438M/3.91G [00:04<00:25, 137MB/s]
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 170M/3.99G [00:04<01:17, 49.5MB/s]
# model-00002-of-00002.safetensors:  12%|▋     | 460M/3.91G [00:04<00:25, 137MB/s]
#
#
# model-00001-of-00002.safetensors:   4%|▏    | 179M/3.99G [00:04<01:14, 51.3MB/s]
#
#
# model-00001-of-00002.safetensors:   5%|▏    | 193M/3.99G [00:05<01:22, 46.0MB/s]
# model-00002-of-00002.safetensors:  14%|▊     | 536M/3.91G [00:05<00:25, 133MB/s]
# model-00002-of-00002.safetensors:  15%|▉     | 603M/3.91G [00:05<00:18, 182MB/s]
# model-00002-of-00002.safetensors:  17%|█     | 652M/3.91G [00:05<00:17, 190MB/s]
# model-00002-of-00002.safetensors:  18%|█     | 710M/3.91G [00:06<00:15, 200MB/s]
#
#
# model-00001-of-00002.safetensors:   5%|▎    | 200M/3.99G [00:06<02:11, 28.8MB/s]
#
#
# model-00001-of-00002.safetensors:   7%|▎    | 267M/3.99G [00:06<00:49, 74.9MB/s]
# model-00002-of-00002.safetensors:  20%|█▏    | 781M/3.91G [00:06<00:14, 219MB/s]
#
#
# model-00001-of-00002.safetensors:   9%|▌     | 342M/3.99G [00:06<00:30, 121MB/s]
# model-00002-of-00002.safetensors:  22%|█▎    | 848M/3.91G [00:06<00:12, 244MB/s]
#
#
# model-00001-of-00002.safetensors:   9%|▌     | 378M/3.99G [00:06<00:27, 133MB/s]
# model-00002-of-00002.safetensors:  24%|█▍    | 928M/3.91G [00:06<00:10, 288MB/s]
#
#
# model-00001-of-00002.safetensors:  12%|▋     | 476M/3.99G [00:06<00:15, 229MB/s]
#
#
# model-00001-of-00002.safetensors:  14%|▊     | 543M/3.99G [00:07<00:13, 255MB/s]
# model-00002-of-00002.safetensors:  25%|█▌    | 995M/3.91G [00:07<00:11, 253MB/s]
# model-00002-of-00002.safetensors:  26%|█▎   | 1.02G/3.91G [00:07<00:11, 247MB/s]
#
#
# model-00001-of-00002.safetensors:  15%|▉     | 609M/3.99G [00:07<00:12, 265MB/s]
#
#
# model-00001-of-00002.safetensors:  17%|█     | 682M/3.99G [00:07<00:10, 312MB/s]
#
#
# model-00001-of-00002.safetensors:  19%|█▏    | 754M/3.99G [00:07<00:09, 354MB/s]
#
#
# model-00001-of-00002.safetensors:  20%|█▏    | 796M/3.99G [00:07<00:08, 366MB/s]
# model-00002-of-00002.safetensors:  28%|█▍   | 1.09G/3.91G [00:07<00:16, 174MB/s]
#
#
# model-00001-of-00002.safetensors:  22%|█▎    | 876M/3.99G [00:07<00:07, 394MB/s]
# model-00002-of-00002.safetensors:  31%|█▌   | 1.21G/3.91G [00:08<00:12, 224MB/s]
#
#
# model-00001-of-00002.safetensors:  23%|█▍    | 922M/3.99G [00:08<00:12, 244MB/s]
#
#
# model-00001-of-00002.safetensors:  24%|█▍    | 961M/3.99G [00:08<00:11, 261MB/s]
# model-00002-of-00002.safetensors:  32%|█▌   | 1.24G/3.91G [00:08<00:13, 192MB/s]
#
#
# model-00001-of-00002.safetensors:  25%|█▎   | 1.00G/3.99G [00:08<00:15, 191MB/s]
#
#
# model-00001-of-00002.safetensors:  26%|█▎   | 1.04G/3.99G [00:08<00:13, 215MB/s]
# model-00002-of-00002.safetensors:  32%|█▌   | 1.27G/3.91G [00:09<00:18, 142MB/s]
#
#
# model-00001-of-00002.safetensors:  28%|█▍   | 1.12G/3.99G [00:08<00:09, 307MB/s]
# model-00002-of-00002.safetensors:  33%|█▋   | 1.31G/3.91G [00:09<00:16, 155MB/s]
#
#
# model-00001-of-00002.safetensors:  31%|█▌   | 1.22G/3.99G [00:09<00:08, 343MB/s]
#
#
# model-00001-of-00002.safetensors:  33%|█▋   | 1.30G/3.99G [00:09<00:06, 409MB/s]
#
#
# model-00001-of-00002.safetensors:  34%|█▋   | 1.37G/3.99G [00:09<00:05, 441MB/s]
# model-00002-of-00002.safetensors:  34%|█▋   | 1.35G/3.91G [00:09<00:20, 128MB/s]
# model-00002-of-00002.safetensors:  36%|█▊   | 1.40G/3.91G [00:09<00:14, 171MB/s]
# model-00002-of-00002.safetensors:  37%|█▊   | 1.46G/3.91G [00:10<00:15, 161MB/s]
#
#
# model-00001-of-00002.safetensors:  36%|█▊   | 1.44G/3.99G [00:10<00:10, 240MB/s]
#
#
# model-00001-of-00002.safetensors:  41%|██   | 1.63G/3.99G [00:10<00:05, 434MB/s]
# model-00002-of-00002.safetensors:  38%|█▉   | 1.48G/3.91G [00:10<00:17, 141MB/s]
# model-00002-of-00002.safetensors:  40%|█▉   | 1.55G/3.91G [00:10<00:11, 198MB/s]
# model-00002-of-00002.safetensors:  40%|██   | 1.58G/3.91G [00:10<00:12, 182MB/s]
# model-00002-of-00002.safetensors:  41%|██   | 1.61G/3.91G [00:11<00:13, 171MB/s]
#
#
# model-00001-of-00002.safetensors:  44%|██▏  | 1.77G/3.99G [00:11<00:07, 282MB/s]
# model-00002-of-00002.safetensors:  42%|██   | 1.63G/3.91G [00:11<00:13, 172MB/s]
# model-00002-of-00002.safetensors:  43%|██▏  | 1.68G/3.91G [00:11<00:11, 198MB/s]
# model-00002-of-00002.safetensors:  44%|██▏  | 1.72G/3.91G [00:11<00:09, 221MB/s]
#
#
# model-00001-of-00002.safetensors:  46%|██▎  | 1.83G/3.99G [00:11<00:09, 224MB/s]
# model-00002-of-00002.safetensors:  45%|██▎  | 1.76G/3.91G [00:11<00:10, 204MB/s]
# model-00002-of-00002.safetensors:  46%|██▎  | 1.78G/3.91G [00:11<00:11, 180MB/s]
#
#
# model-00001-of-00002.safetensors:  47%|██▎  | 1.88G/3.99G [00:11<00:10, 205MB/s]
# model-00002-of-00002.safetensors:  47%|██▎  | 1.85G/3.91G [00:12<00:12, 166MB/s]
#
#
# model-00001-of-00002.safetensors:  49%|██▍  | 1.95G/3.99G [00:12<00:10, 190MB/s]
# model-00002-of-00002.safetensors:  49%|██▍  | 1.91G/3.91G [00:12<00:11, 177MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|██▍  | 1.99G/3.99G [00:12<00:10, 187MB/s]
# model-00002-of-00002.safetensors:  51%|██▌  | 1.98G/3.91G [00:12<00:08, 231MB/s]
#
#
# model-00001-of-00002.safetensors:  50%|██▌  | 2.01G/3.99G [00:12<00:10, 188MB/s]
# model-00002-of-00002.safetensors:  52%|██▌  | 2.02G/3.91G [00:12<00:07, 247MB/s]
# model-00002-of-00002.safetensors:  53%|██▋  | 2.09G/3.91G [00:13<00:06, 297MB/s]
#
#
# model-00001-of-00002.safetensors:  52%|██▌  | 2.06G/3.99G [00:12<00:10, 180MB/s]
# model-00002-of-00002.safetensors:  56%|██▊  | 2.19G/3.91G [00:13<00:05, 334MB/s]
#
#
# model-00001-of-00002.safetensors:  53%|██▋  | 2.11G/3.99G [00:13<00:11, 171MB/s]
# model-00002-of-00002.safetensors:  58%|██▉  | 2.26G/3.91G [00:13<00:04, 333MB/s]
# model-00002-of-00002.safetensors:  59%|██▉  | 2.29G/3.91G [00:13<00:04, 325MB/s]
#
#
# model-00001-of-00002.safetensors:  54%|██▋  | 2.14G/3.99G [00:13<00:11, 160MB/s]
# model-00002-of-00002.safetensors:  60%|███  | 2.36G/3.91G [00:13<00:04, 352MB/s]
#
#
# model-00001-of-00002.safetensors:  55%|██▋  | 2.18G/3.99G [00:13<00:14, 129MB/s]
# model-00002-of-00002.safetensors:  62%|███  | 2.43G/3.91G [00:14<00:05, 289MB/s]
#
#
# Fetching 12 files:  50%|████████████▌            | 6/12 [00:14<00:00, 15.79it/s]
#
#
# model-00001-of-00002.safetensors:  57%|██▊  | 2.27G/3.99G [00:14<00:12, 142MB/s]
# model-00002-of-00002.safetensors:  64%|███▏ | 2.51G/3.91G [00:14<00:06, 225MB/s]
#
#
# model-00001-of-00002.safetensors:  58%|██▉  | 2.32G/3.99G [00:14<00:10, 157MB/s]
# model-00002-of-00002.safetensors:  66%|███▎ | 2.58G/3.91G [00:14<00:05, 236MB/s]
#
#
# model-00001-of-00002.safetensors:  59%|██▉  | 2.36G/3.99G [00:15<00:11, 141MB/s]
# model-00002-of-00002.safetensors:  67%|███▎ | 2.63G/3.91G [00:15<00:06, 192MB/s]
#
#
# model-00001-of-00002.safetensors:  60%|██▉  | 2.39G/3.99G [00:15<00:10, 157MB/s]
# model-00002-of-00002.safetensors:  69%|███▍ | 2.71G/3.91G [00:15<00:05, 240MB/s]
#
#
# model-00001-of-00002.safetensors:  61%|███  | 2.42G/3.99G [00:15<00:09, 159MB/s]
# model-00002-of-00002.safetensors:  70%|███▌ | 2.74G/3.91G [00:15<00:04, 259MB/s]
# model-00002-of-00002.safetensors:  73%|███▋ | 2.85G/3.91G [00:15<00:03, 338MB/s]
# model-00002-of-00002.safetensors:  75%|███▋ | 2.93G/3.91G [00:15<00:02, 395MB/s]
# model-00002-of-00002.safetensors:  76%|███▊ | 2.98G/3.91G [00:16<00:02, 393MB/s]
#
#
# model-00001-of-00002.safetensors:  61%|███  | 2.45G/3.99G [00:15<00:14, 105MB/s]
# model-00002-of-00002.safetensors:  78%|███▉ | 3.05G/3.91G [00:16<00:02, 401MB/s]
#
#
# model-00001-of-00002.safetensors:  63%|███▏ | 2.50G/3.99G [00:16<00:10, 138MB/s]
#
#
# model-00001-of-00002.safetensors:  64%|███▏ | 2.54G/3.99G [00:16<00:09, 154MB/s]
#
#
# model-00001-of-00002.safetensors:  66%|███▎ | 2.64G/3.99G [00:16<00:06, 220MB/s]
# model-00002-of-00002.safetensors:  79%|███▉ | 3.11G/3.91G [00:16<00:04, 199MB/s]
#
#
# model-00001-of-00002.safetensors:  68%|███▍ | 2.72G/3.99G [00:16<00:04, 272MB/s]
#
#
# model-00001-of-00002.safetensors:  69%|███▍ | 2.75G/3.99G [00:16<00:04, 274MB/s]
# model-00002-of-00002.safetensors:  81%|████ | 3.15G/3.91G [00:17<00:03, 208MB/s]
#
#
# model-00001-of-00002.safetensors:  70%|███▍ | 2.78G/3.99G [00:17<00:04, 253MB/s]
# model-00002-of-00002.safetensors:  83%|████▏| 3.24G/3.91G [00:17<00:02, 278MB/s]
#
#
# model-00001-of-00002.safetensors:  72%|███▌ | 2.86G/3.99G [00:17<00:03, 331MB/s]
#
#
# model-00001-of-00002.safetensors:  73%|███▋ | 2.90G/3.99G [00:17<00:03, 331MB/s]
# model-00002-of-00002.safetensors:  84%|████▏| 3.29G/3.91G [00:17<00:02, 267MB/s]
#
#
# model-00001-of-00002.safetensors:  74%|███▋ | 2.94G/3.99G [00:17<00:03, 276MB/s]
#
#
# model-00001-of-00002.safetensors:  75%|███▊ | 3.00G/3.99G [00:17<00:03, 318MB/s]
#
#
# model-00001-of-00002.safetensors:  76%|███▊ | 3.04G/3.99G [00:17<00:03, 300MB/s]
# model-00002-of-00002.safetensors:  87%|████▎| 3.39G/3.91G [00:18<00:02, 213MB/s]
#
#
# model-00001-of-00002.safetensors:  77%|███▊ | 3.08G/3.99G [00:17<00:03, 302MB/s]
#
#
# model-00001-of-00002.safetensors:  78%|███▉ | 3.12G/3.99G [00:18<00:02, 328MB/s]
# model-00002-of-00002.safetensors:  88%|████▍| 3.43G/3.91G [00:18<00:02, 205MB/s]
#
#
# model-00001-of-00002.safetensors:  79%|███▉ | 3.17G/3.99G [00:18<00:03, 256MB/s]
#
#
# model-00001-of-00002.safetensors:  81%|████ | 3.21G/3.99G [00:18<00:02, 269MB/s]
# model-00002-of-00002.safetensors:  89%|████▍| 3.47G/3.91G [00:18<00:02, 165MB/s]
#
#
# model-00001-of-00002.safetensors:  81%|████ | 3.24G/3.99G [00:18<00:02, 262MB/s]
#
#
# model-00001-of-00002.safetensors:  82%|████ | 3.28G/3.99G [00:18<00:02, 271MB/s]
#
#
# model-00001-of-00002.safetensors:  83%|████▏| 3.33G/3.99G [00:18<00:02, 312MB/s]
# model-00002-of-00002.safetensors:  90%|████▍| 3.50G/3.91G [00:19<00:02, 140MB/s]
#
#
# model-00001-of-00002.safetensors:  85%|████▎| 3.40G/3.99G [00:19<00:01, 335MB/s]
# model-00002-of-00002.safetensors:  91%|████▌| 3.57G/3.91G [00:19<00:01, 190MB/s]
#
#
# model-00001-of-00002.safetensors:  86%|████▎| 3.44G/3.99G [00:19<00:01, 314MB/s]
#
#
# model-00001-of-00002.safetensors:  87%|████▎| 3.48G/3.99G [00:19<00:01, 322MB/s]
#
#
# model-00001-of-00002.safetensors:  90%|████▍| 3.58G/3.99G [00:19<00:00, 466MB/s]
# model-00002-of-00002.safetensors:  92%|████▌| 3.61G/3.91G [00:19<00:01, 157MB/s]
#
#
# model-00001-of-00002.safetensors:  91%|████▌| 3.64G/3.99G [00:19<00:00, 402MB/s]
#
#
# model-00001-of-00002.safetensors:  93%|████▋| 3.72G/3.99G [00:19<00:00, 411MB/s]
#
#
# model-00001-of-00002.safetensors:  96%|████▊| 3.82G/3.99G [00:19<00:00, 463MB/s]
# model-00002-of-00002.safetensors:  94%|███▊| 3.69G/3.91G [00:21<00:02, 78.0MB/s]
#
#
# model-00001-of-00002.safetensors:  98%|████▉| 3.89G/3.99G [00:21<00:00, 145MB/s]
# model-00002-of-00002.safetensors:  97%|████▊| 3.79G/3.91G [00:21<00:00, 120MB/s]
#
#
# model-00001-of-00002.safetensors: 100%|█████| 3.99G/3.99G [00:21<00:00, 185MB/s]
# Fetching 12 files:  58%|██████████████▌          | 7/12 [00:21<00:21,  4.33s/it]
# model-00002-of-00002.safetensors: 100%|█████| 3.91G/3.91G [00:21<00:00, 179MB/s]
# Fetching 12 files: 100%|████████████████████████| 12/12 [00:21<00:00,  1.83s/it]
# Successfully downloaded Qwen/Qwen1.5-4B-Chat
# Downloading Qwen/Qwen1.5-1.8B-Chat to models/LLM/Qwen1.5-1.8B-Chat (Attempt 1/5)...
# Fetching 10 files:   0%|                                 | 0/10 [00:00<?, ?it/s]
# merges.txt: 0.00B [00:00, ?B/s]
#
# .gitattributes: 1.52kB [00:00, 7.70MB/s]A
#
#
# model.safetensors:   0%|                            | 0.00/3.67G [00:00<?, ?B/s]
#
#
# merges.txt: 1.67MB [00:00, 31.7MB/s][A
# tokenizer.json: 7.03MB [00:00, 129MB/s]
#
# tokenizer_config.json: 1.29kB [00:00, 9.15MB/s]
#
# generation_config.json: 100%|██████████████████| 206/206 [00:00<00:00, 1.89MB/s]
#
# config.json: 100%|█████████████████████████████| 662/662 [00:00<00:00, 5.59MB/s]
#
# vocab.json: 2.78MB [00:00, 127MB/s]
#
# LICENSE: 7.28kB [00:00, 267kB/s]
# Fetching 10 files:  20%|█████                    | 2/10 [00:00<00:01,  7.10it/s]
# README.md: 4.28kB [00:00, 16.3MB/s]
# Fetching 10 files:  30%|███████▌                 | 3/10 [00:00<00:01,  4.31it/s]
#
# model.safetensors:   0%|                   | 7.98M/3.67G [00:01<09:33, 6.39MB/s]
#
# model.safetensors:   1%|▎                  | 52.6M/3.67G [00:01<01:17, 46.7MB/s]
#
# model.safetensors:   3%|▋                    | 120M/3.67G [00:01<00:30, 118MB/s]
#
# model.safetensors:   4%|▊                   | 156M/3.67G [00:02<00:36, 97.2MB/s]
#
# model.safetensors:   5%|█                   | 185M/3.67G [00:02<00:35, 97.4MB/s]
#
# model.safetensors:   6%|█▏                  | 209M/3.67G [00:02<00:37, 91.9MB/s]
#
# model.safetensors:   6%|█▎                  | 231M/3.67G [00:02<00:36, 94.8MB/s]
#
# model.safetensors:   7%|█▍                   | 262M/3.67G [00:02<00:28, 121MB/s]
#
# model.safetensors:   8%|█▋                   | 289M/3.67G [00:03<00:29, 113MB/s]
#
# model.safetensors:   8%|█▊                   | 309M/3.67G [00:03<00:28, 117MB/s]
#
# model.safetensors:   9%|█▊                   | 326M/3.67G [00:03<00:26, 126MB/s]
#
# model.safetensors:   9%|█▉                   | 343M/3.67G [00:03<00:24, 134MB/s]
#
# model.safetensors:  11%|██▍                  | 419M/3.67G [00:03<00:19, 168MB/s]
#
# model.safetensors:  13%|██▋                  | 468M/3.67G [00:04<00:14, 219MB/s]
#
# model.safetensors:  14%|██▉                  | 507M/3.67G [00:04<00:17, 186MB/s]
#
# model.safetensors:  15%|███▏                 | 558M/3.67G [00:04<00:13, 224MB/s]
#
# model.safetensors:  16%|███▍                 | 598M/3.67G [00:04<00:12, 246MB/s]
#
# model.safetensors:  18%|███▊                 | 670M/3.67G [00:04<00:10, 293MB/s]
#
# model.safetensors:  21%|████▎                | 763M/3.67G [00:04<00:07, 409MB/s]
#
# model.safetensors:  22%|████▋                | 818M/3.67G [00:05<00:06, 426MB/s]
#
# model.safetensors:  24%|████▉                | 868M/3.67G [00:05<00:06, 430MB/s]
#
# model.safetensors:  25%|█████▎               | 929M/3.67G [00:06<00:16, 166MB/s]
#
# model.safetensors:  38%|███████▋            | 1.40G/3.67G [00:06<00:03, 604MB/s]
#
# model.safetensors:  41%|████████▏           | 1.51G/3.67G [00:06<00:03, 650MB/s]
#
# model.safetensors:  44%|████████▊           | 1.62G/3.67G [00:06<00:04, 491MB/s]
#
# model.safetensors:  48%|█████████▌          | 1.75G/3.67G [00:06<00:03, 501MB/s]
#
# model.safetensors:  50%|██████████          | 1.84G/3.67G [00:07<00:04, 423MB/s]
#
# model.safetensors:  52%|██████████▍         | 1.91G/3.67G [00:08<00:08, 202MB/s]
#
# model.safetensors:  53%|██████████▋         | 1.95G/3.67G [00:08<00:07, 218MB/s]
#
# model.safetensors:  57%|███████████▍        | 2.11G/3.67G [00:08<00:04, 320MB/s]
#
# model.safetensors:  59%|███████████▉        | 2.18G/3.67G [00:08<00:04, 341MB/s]
#
# model.safetensors:  61%|████████████▏       | 2.24G/3.67G [00:09<00:03, 360MB/s]
#
# model.safetensors:  62%|████████████▍       | 2.29G/3.67G [00:09<00:04, 336MB/s]
#
# model.safetensors:  64%|████████████▋       | 2.34G/3.67G [00:09<00:03, 344MB/s]
#
# model.safetensors:  65%|████████████▉       | 2.38G/3.67G [00:10<00:10, 124MB/s]
#
# model.safetensors:  67%|█████████████▎      | 2.45G/3.67G [00:10<00:07, 161MB/s]
#
# model.safetensors:  68%|█████████████▌      | 2.48G/3.67G [00:10<00:06, 176MB/s]
#
# model.safetensors:  69%|█████████████▋      | 2.53G/3.67G [00:10<00:05, 202MB/s]
#
# model.safetensors:  70%|█████████████▉      | 2.57G/3.67G [00:11<00:04, 221MB/s]
#
# model.safetensors:  71%|██████████████▏     | 2.61G/3.67G [00:11<00:04, 228MB/s]
#
# model.safetensors:  73%|██████████████▋     | 2.69G/3.67G [00:11<00:03, 318MB/s]
#
# model.safetensors:  75%|██████████████▉     | 2.75G/3.67G [00:11<00:02, 343MB/s]
#
# model.safetensors:  76%|███████████████▎    | 2.81G/3.67G [00:11<00:02, 386MB/s]
#
# model.safetensors:  78%|███████████████▌    | 2.85G/3.67G [00:11<00:02, 405MB/s]
#
# model.safetensors:  79%|███████████████▉    | 2.92G/3.67G [00:11<00:01, 429MB/s]
#
# model.safetensors:  81%|████████████████▏   | 2.97G/3.67G [00:11<00:02, 349MB/s]
#
# model.safetensors:  82%|████████████████▍   | 3.01G/3.67G [00:12<00:01, 341MB/s]
#
# model.safetensors:  83%|████████████████▋   | 3.06G/3.67G [00:12<00:01, 321MB/s]
#
# model.safetensors:  84%|████████████████▊   | 3.10G/3.67G [00:12<00:02, 218MB/s]
#
# model.safetensors:  86%|█████████████████▎  | 3.17G/3.67G [00:12<00:01, 251MB/s]
#
# model.safetensors:  87%|█████████████████▍  | 3.20G/3.67G [00:13<00:01, 248MB/s]
#
# model.safetensors:  88%|█████████████████▌  | 3.23G/3.67G [00:13<00:01, 254MB/s]
#
# model.safetensors:  90%|██████████████████  | 3.32G/3.67G [00:13<00:00, 358MB/s]
#
# model.safetensors:  92%|██████████████████▍ | 3.38G/3.67G [00:14<00:02, 123MB/s]
#
# model.safetensors:  94%|██████████████████▊ | 3.46G/3.67G [00:14<00:01, 185MB/s]
#
# model.safetensors:  97%|███████████████████▎| 3.55G/3.67G [00:14<00:00, 261MB/s]
#
# model.safetensors: 100%|████████████████████| 3.67G/3.67G [00:14<00:00, 249MB/s]
# Fetching 10 files: 100%|████████████████████████| 10/10 [00:14<00:00,  1.48s/it]
# Successfully downloaded Qwen/Qwen1.5-1.8B-Chat
# Downloading Systran/faster-whisper-large-v3 to models/ASR/whisper/faster-whisper-large-v3 (Attempt 1/5)...
# Fetching 7 files:   0%|                                   | 0/7 [00:00<?, ?it/s]
# config.json: 2.39kB [00:00, 16.0MB/s]
#
# vocabulary.json: 0.00B [00:00, ?B/s]
#
# README.md: 2.05kB [00:00, 12.3MB/s]A
# vocabulary.json: 1.07MB [00:00, 99.2MB/s]
#
# preprocessor_config.json: 100%|████████████████| 340/340 [00:00<00:00, 3.88MB/s]
#
# model.bin:   0%|                                    | 0.00/3.09G [00:00<?, ?B/s]
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
#
# .gitattributes: 1.52kB [00:00, 3.51MB/s]A
# tokenizer.json: 2.48MB [00:00, 143MB/s]           | 1/7 [00:00<00:01,  5.42it/s]
#
# model.bin:   0%|                           | 1.32M/3.09G [00:00<23:15, 2.21MB/s]
# model.bin:   0%|                           | 4.04M/3.09G [00:00<11:05, 4.63MB/s]
# model.bin:   0%|                           | 8.26M/3.09G [00:01<07:04, 7.25MB/s]
# model.bin:   2%|▋                          | 75.3M/3.09G [00:03<01:37, 30.7MB/s]
# model.bin:   5%|█▎                          | 142M/3.09G [00:03<00:48, 60.6MB/s]
# model.bin:   7%|█▉                          | 209M/3.09G [00:03<00:29, 97.1MB/s]
# model.bin:   9%|██▌                          | 276M/3.09G [00:03<00:21, 131MB/s]
# model.bin:  11%|███▏                         | 343M/3.09G [00:03<00:16, 163MB/s]
# model.bin:  13%|███▊                         | 410M/3.09G [00:04<00:15, 168MB/s]
# model.bin:  15%|████▍                        | 478M/3.09G [00:04<00:13, 188MB/s]
# model.bin:  18%|█████                        | 545M/3.09G [00:04<00:11, 229MB/s]
# model.bin:  22%|██████▎                      | 679M/3.09G [00:04<00:07, 335MB/s]
# model.bin:  24%|███████                      | 746M/3.09G [00:05<00:06, 370MB/s]
# model.bin:  28%|████████▎                    | 880M/3.09G [00:05<00:06, 356MB/s]
# model.bin:  33%|█████████▏                  | 1.01G/3.09G [00:05<00:04, 446MB/s]
# model.bin:  35%|█████████▊                  | 1.08G/3.09G [00:05<00:04, 471MB/s]
# model.bin:  37%|██████████▍                 | 1.15G/3.09G [00:05<00:03, 502MB/s]
# model.bin:  42%|███████████▌                | 1.28G/3.09G [00:06<00:03, 594MB/s]
# model.bin:  46%|████████████▊               | 1.42G/3.09G [00:06<00:02, 668MB/s]
# model.bin:  50%|██████████████              | 1.55G/3.09G [00:06<00:02, 710MB/s]
# model.bin:  54%|███████████████▎            | 1.68G/3.09G [00:07<00:05, 260MB/s]
# model.bin:  59%|████████████████▍           | 1.82G/3.09G [00:07<00:03, 337MB/s]
# model.bin:  63%|█████████████████▋          | 1.95G/3.09G [00:07<00:02, 403MB/s]
# model.bin:  68%|██████████████████▉         | 2.08G/3.09G [00:08<00:03, 300MB/s]
# model.bin:  70%|███████████████████▌        | 2.15G/3.09G [00:08<00:02, 329MB/s]
# model.bin:  72%|████████████████████        | 2.22G/3.09G [00:08<00:02, 351MB/s]
# model.bin:  74%|████████████████████▋       | 2.29G/3.09G [00:09<00:02, 325MB/s]
# model.bin:  76%|█████████████████████▎      | 2.35G/3.09G [00:09<00:02, 306MB/s]
# model.bin:  78%|█████████████████████▉      | 2.42G/3.09G [00:10<00:03, 202MB/s]
# model.bin:  83%|███████████████████████▏    | 2.55G/3.09G [00:10<00:01, 302MB/s]
# model.bin:  85%|███████████████████████▋    | 2.62G/3.09G [00:10<00:01, 287MB/s]
# model.bin:  87%|████████████████████████▎   | 2.69G/3.09G [00:11<00:02, 148MB/s]
# model.bin:  91%|█████████████████████████▌  | 2.82G/3.09G [00:11<00:01, 231MB/s]
# model.bin:  96%|██████████████████████████▊ | 2.95G/3.09G [00:11<00:00, 324MB/s]
# model.bin: 100%|████████████████████████████| 3.09G/3.09G [00:11<00:00, 258MB/s]
# Fetching 7 files: 100%|███████████████████████████| 7/7 [00:12<00:00,  1.73s/it]
# Successfully downloaded Systran/faster-whisper-large-v3
#
# ✅ Step 3 Complete!

# %%
# ============================================================================
# Step 4: Launch WebUI
# ============================================================================

import os
import sys

print("=" * 60)
print("🚀 Launching Linly-Dubbing WebUI")
print("=" * 60)

# Ensure submodules are in path (Fallback for installation issues)
project_root = '/kaggle/working/Linly-Dubbing'
submodule_paths = [
    os.path.join(project_root, 'submodules/demucs'),
    os.path.join(project_root, 'submodules/whisper'),
    os.path.join(project_root, 'submodules/whisperX'),
    os.path.join(project_root, 'submodules/TTS')
]
for p in submodule_paths:
    if os.path.exists(p) and p not in sys.path:
        sys.path.append(p)  # Use append to avoid shadowing project tools

# Set environment variables
os.environ['PYTHONPATH'] = ':'.join(submodule_paths) + (':' + os.environ.get('PYTHONPATH', '') if os.environ.get('PYTHONPATH') else '')
os.environ['MPLBACKEND'] = 'Agg'

if not os.path.exists('.env'):
    # !cp env.example .env

# Verify critical imports before launch
print("\n🔍 Verifying critical imports...")
try:
    from tools.step000_video_downloader import download_from_url##
    from tools.step010_demucs_vr import separate_all_audio_under_folder
    print("✅ All critical modules imported successfully")
except ImportError as e:
    print(f"❌ Import error: {e}")
    print("\n🔧 Attempting to fix missing dependencies...")
    # Install missing dora if needed
    # !pip install -q dora-search
    print("Please re-run this cell after installing missing dependencies.")
    raise

print("\n🌐 Starting Gradio WebUI...")
# !python webui.py
# Out:
# ============================================================
# 🚀 Launching Linly-Dubbing WebUI
# ============================================================
#
# 🔍 Verifying critical imports...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_55/1456168969.py in <cell line: 0>()
#      33 try:
#      34     from tools.step000_video_downloader import download_from_url##
# ---> 35     from tools.step010_demucs_vr import separate_all_audio_under_folder
#      36     print("✅ All critical modules imported successfully")
#      37 except ImportError as e:
#
# /kaggle/working/Linly-Dubbing/tools/step010_demucs_vr.py in <module>
#       4 from loguru import logger
#       5 import time
# ----> 6 from .utils import save_wav, normalize_wav
#       7 import torch
#       8 import gc
#
# /kaggle/working/Linly-Dubbing/tools/utils.py in <module>
#       2 import string
#       3 import numpy as np
# ----> 4 from scipy.io import wavfile
#       5
#       6 def sanitize_filename(filename: str) -> str:
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/__init__.py in <module>
#     100 """
#     101 # matfile read and write
# --> 102 from .matlab import loadmat, savemat, whosmat
#     103
#     104 # netCDF file support
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/matlab/__init__.py in <module>
#      45 """
#      46 # Matlab file read and write utilities
# ---> 47 from ._mio import loadmat, savemat, whosmat
#      48 from ._mio5 import MatlabFunction, varmats_from_mat
#      49 from ._mio5_params import MatlabObject, MatlabOpaque, mat_struct
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/matlab/_mio.py in <module>
#       7
#       8 from ._miobase import _get_matfile_version, docfiller
# ----> 9 from ._mio4 import MatFile4Reader, MatFile4Writer
#      10 from ._mio5 import MatFile5Reader, MatFile5Writer
#      11
#
# /usr/local/lib/python3.12/dist-packages/scipy/io/matlab/_mio4.py in <module>
#       8 import numpy as np
#       9
# ---> 10 import scipy.sparse
#      11
#      12 from ._miobase import (MatFileReader, docfiller, matdims, read_dtype,
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/__init__.py in <module>
#     305 import importlib as _importlib
#     306
# --> 307 from ._base import *
#     308 from ._csr import *
#     309 from ._csc import *
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_base.py in <module>
#       6 import operator
#       7
# ----> 8 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       9                        get_sum_dtype, isdense, isscalarlike, _todata,
#      10                        matrix, validateaxis, getdtype, is_pydata_spmatrix)
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_sputils.py in <module>
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      11
#      12
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py in <module>
#      15
#      16 import numpy as np
# ---> 17 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array, is_numpy,
#      18                                    is_marray, xp_size, xp_result_device, xp_result_type)
#      19 from scipy._lib._docscrape import FunctionDoc, Parameter
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_array_api.py in <module>
#      22 import numpy.typing as npt
#      23
# ---> 24 from scipy._lib.array_api_compat import (
#      25     is_array_api_obj,
#      26     is_lazy_array,
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/array_api_compat/numpy/__init__.py in <module>
#       7 import numpy.typing  # noqa: F401
#       8
# ----> 9 __all__ = clone_module("numpy", globals())
#      10
#      11 # These imports may overwrite names from the import * above.
#
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/array_api_compat/_internal.py in clone_module(mod_name, globals_)
#      62     # depending on various idiosyncrasies of the libraries we're wrapping.
#      63     objs = {}
# ---> 64     exec(f"from {mod.__name__} import *", objs)
#      65
#      66     for n in dir(mod):
#
# <string> in <module>
#
# /usr/local/lib/python3.12/dist-packages/numpy/testing/__init__.py in <module>
#      10 from . import _private, overrides
#      11 from ._private import extbuild
# ---> 12 from ._private.utils import *
#      13 from ._private.utils import _assert_valid_refcount, _gen_alignment_data
#      14
#
# /usr/local/lib/python3.12/dist-packages/numpy/testing/_private/utils.py in <module>
#      91 IS_PYSTON = hasattr(sys, "pyston_version_info")
#      92 HAS_REFCOUNT = getattr(sys, 'getrefcount', None) is not None and not IS_PYSTON
# ---> 93 BLAS_SUPPORTS_FPE = np._core._multiarray_umath._blas_supports_fpe(None)
#      94
#      95 HAS_LAPACK64 = numpy.linalg._umath_linalg._ilp64
#
# AttributeError: module 'numpy._core._multiarray_umath' has no attribute '_blas_supports_fpe'
